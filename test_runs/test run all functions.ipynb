# %%
import json
import sys
import pandas as pd
from matplotlib import pyplot as plt
import requests
from keys import client_id, api_key

# %%
## style for notebook & plots - in matplotlib bookmark ##
style = 'dark_background'
plt.style.use(style)

# %%
# SEARCH PARAMETERS
url =  "https://api.yelp.com/v3/businesses/search"
term = 'Indian'
location = 'Washington, D.C.'
categories = "restaurants"
radius = 100

# HEADERS
headers = {'Authorization': 'Bearer {}'.format(api_key),
    }

# URL PARAMETERS
url_params = {"term": term.replace(' ', '+'),
                "location": location.replace(' ', '+'),
                "categories" : categories,
                "limit": 50,
                }

# RESPONSE FROM API SERVER
response = requests.get(url, headers = headers, params = url_params)

# %%
def yelp_call(url, url_params, api_key):
#THIS FUNCTION IS CALLED TO MAKE API CALL TO YELP AND RETURN THE RESPONSE

    headers = {'Authorization': 'Bearer {}'.format(api_key),}

    response = requests.get(url, headers = headers, params = url_params)
#    response.status_code
#    response.text

    return response

# %%
def parse_data(list_of_data):
#THIS FUNCTION CREATES A TUPLE OF BUSINESS INFORMATION FOR ALL BUSINESSES CAPTURED VIA YELP
# INCLUDES CONVERSION FOR CHANGING "$$" TO NUM FOR PRICE REPRESENTATION
    businesses=[]
    
    for business in list_of_data:
        get_categories = parse_categories(business['categories'])    
        num_categories = len(get_categories)
        if 'price' in business.keys():
            price_val = len(business['price'])
        else:
            price_val = 0
        biz_tuple = (business['id'], business['name'], get_categories, num_categories, price_val, business['review_count'], business['rating'], business['location']['address1'], 
                     business['location']['city'], business['location']['state'], business['location']['zip_code'])
        businesses.append(biz_tuple)

    return businesses

# %%
def parse_results(results):
# THIS FUNCTION TAKES RESULTS RETURNED FROM YELP API, PARSES THE DATA, AND STORES AS A DATAFRAME

    #EITHER ONE WORKS
    #data = json.loads(response.text)
    data = results.json()
    num = data['total']
    
    parsed_results = parse_data(data['businesses'])
    df = pd.DataFrame(parsed_results, columns=['business_id', 'name', 'categories', 'num_categories', 'price', 'review_count', 'rating', 'street_address', 'city', 'state', 'zip_code'])
    return df, num

# %%
def parse_categories(categories_list):
# THIS FUNCTION TAKES THE LIST OF CATEGORIES FROM A BUSINESS AND CREATES A LIST OF CATEGORIES OF THE BUSINESS

    list_of_categories = []
    x_len = len(categories_list)
    for x in range(0,x_len):
        list_of_categories.append(categories_list[x]['alias'])
    return list_of_categories

# %%
def df_save(csv_filepath, parsed_results):
# THIS FUNCTION SAVES A DATAFRAME AS A CSV FILE
    
    f = open(csv_filepath, 'a', encoding="utf-8")
    parsed_results.to_csv(f, header=False)
    f.close()

# %%
def get_yelp_reviews(business_id):
# THIS FUNCTION CALLS YELP API TO RETRIEVE ALL REVIEWS FOR A GIVEN BUSINESS ID

    business_reviews = []
    headers = {'Authorization': 'Bearer {}'.format(api_key),}
    url =  "https://api.yelp.com/v3/businesses/{}/reviews".format(business_id)

    review_response = requests.get(url, headers = headers)
    review_data = json.loads(review_response.text)
        
    for review in review_data['reviews']:
        review_tuple = (business_id, review['id'], review['text'], review['rating'], review['time_created'])
        business_reviews.append(review_tuple)

    return business_reviews

# %%
def generate_all_reviews(businesses_list):
# THIS FUNCTION IS CALLED TO CREATE A LIST OF REVIEWS FOR ALL BUSINESSES WITHIN ITS PASSED DATA SET

    all_business_reviews = []

    for biz in businesses_list:
        biz_reviews = get_yelp_reviews(biz)
        for each_business in biz_reviews:
            all_business_reviews.append(each_business)

    reviews_results = pd.DataFrame(all_business_reviews, columns = 
                                   ['business_id', 'review_id', 'text', 'rating', 'time_created'])
     
    return reviews_results

# %%
def generate_all_yelp_data_la():
# THIS FUNCTION IS THE MAIN DRIVER - SETS SEARCH PARAMETERS, CALLS YELP API, 
# PARSES RETURNED DATA AND STORED IN CSV/DATAFRAME

    term = 'Indian'
    location = 'Los Angeles'
    categories = "restaurants"
    radius = 40000
#   price = 4
    
    url =  "https://api.yelp.com/v3/businesses/search"
    url_params = {
                "term": term.replace(' ', '+'),
                "location": location.replace(' ', '+'),
                "categories" : categories,
                "radius" : radius,
                "limit": 50,
#                "price": price,
                }

    all_results_la = pd.DataFrame()
    num = 1
    cur = 0
    
    while (cur < num and cur < 1000):

        url_params['offset'] = cur
        results = yelp_call(url, url_params, api_key)
        parsed_results, num = parse_results(results)
        parsed_reviews = generate_all_reviews(parsed_results.business_id)
        df_save('test_data_la.csv', parsed_results)
        df_save('test_review_la.csv', parsed_reviews)
        all_results_la = all_results_la.append(parsed_results)
        cur += 50

    return all_results_la

# %%
def generate_all_yelp_data_dc():
# THIS FUNCTION IS THE MAIN DRIVER - SETS SEARCH PARAMETERS, CALLS YELP API, 
# PARSES RETURNED DATA AND STORED IN CSV/DATAFRAME

    term = 'Indian'
    location = 'Washington, D.C.'
    categories = "restaurants"
    radius = 40000
#   price = 4
    
    url =  "https://api.yelp.com/v3/businesses/search"
    url_params = {
                "term": term.replace(' ', '+'),
                "location": location.replace(' ', '+'),
                "categories" : categories,
                "radius" : radius,
                "limit": 50,
#                "price": price,
                }

    all_results_dc = pd.DataFrame()
    num = 1
    cur = 0
    
    while (cur < num and cur < 1000):

        url_params['offset'] = cur
        results = yelp_call(url, url_params, api_key)
        parsed_results, num = parse_results(results)
        parsed_reviews = generate_all_reviews(parsed_results.business_id)
        df_save('test_data_dc.csv', parsed_results)
        df_save('test_review_dc.csv', parsed_reviews)
        all_results_dc = all_results_dc.append(parsed_results)
        cur += 50

    return all_results_dc

# %%
all_results_la = generate_all_yelp_data_la()

# %%
all_results_dc = generate_all_yelp_data_dc()

# %%
all_results_la
# Out:
#                business_id                        name  \
# 0   3XTjerBg_PywBN81Ts45Bg          India's Restaurant
# 1   uteG6HIb4an-y5fFCXWo7w  Anarkali Indian Restaurant
# 2   52QPoJFEObNp6f6rv8XthQ            India's Tandoori
# 3   B6fT0KdNWPKH9Yjaz06NiA        Biriyani Kabob House
# 4   2Z7pKTwHhFwuH-aTCgd-Rg            India's Tandoori
# ..                     ...                         ...
# 32  UdWQu4w9l3Y9aKkioWUryw                  Todo Verde
# 33  jIu7TUg3cDAmK07KbwAOKw                 Cafe Sierra
# 34  o5RJUFQJgVhaFRtZpzCfxA                P.F. Chang's
# 35  7tKP4mI07i6A31QVBCr7Jg     California Chicken Cafe
# 36  GYIlrCd5N9z1UNpwKz1rqg             The Luxe Buffet
#
#                              categories  num_categories  price  review_count  \
# 0              [indpak, halal, seafood]               3      2          2951
# 1                              [indpak]               1      2          2974
# 2          [indpak, gluten_free, vegan]               3      2          1192
# 3            [pakistani, halal, indpak]               3      2           908
# 4              [indpak, halal, seafood]               3      2          1463
# ..                                  ...             ...    ...           ...
# 32             [vegan, catering, latin]               3      2            56
# 33      [newamerican, buffets, seafood]               3      3           968
# 34  [chinese, asianfusion, gluten_free]               3      2           716
# 35         [tradamerican, salad, wraps]               3      2           454
# 36            [buffets, sushi, seafood]               3      2          2945
#
#     rating              street_address            city state zip_code
# 0      4.5           4366 Fountain Ave     Los Angeles    CA    90029
# 1      4.5            7013 Melrose Ave     Los Angeles    CA    90038
# 2      4.0         11819 Wilshire Blvd     Los Angeles    CA    90025
# 3      4.5               3525 W 3rd St     Los Angeles    CA    90020
# 4      4.0          5468 Wilshire Blvd     Los Angeles    CA    90036
# ..     ...                         ...             ...   ...      ...
# 32     5.0                        None     Los Angeles    CA    90021
# 33     3.5  555 Universal Hollywood Dr  Universal City    CA    91608
# 34     3.0             21821 Oxnard St  Woodland Hills    CA    91367
# 35     3.5    9045 Topanga Canyon Blvd      Chatsworth    CA    91304
# 36     4.0       2008 Westminster Mall     Westminster    CA    92683
#
# [487 rows x 11 columns]

# %%
all_results_dc
# Out:
#                business_id                               name  \
# 0   n-6O6I7pmmpwkW2pCO-zDw                             Indigo
# 1   CwdlygqT4cWwOtQGsYdoBw                             Rasika
# 2   jxTABk0jP7Y_kN3DCNiWbQ                 Bombay Street Food
# 3   jj1vSlzf-G1_vTJJ6ftsAA                              Pappe
# 4   0CfNGIodfKdoItAmSWgDDg                               RASA
# ..                     ...                                ...
# 31  gujrcV70JVd2dWKBLeZYDA               Hamrock's Restaurant
# 32  um6BMlvfsdJPGlD36HrvSA             Lucky Kabob Food Truck
# 33  THpvo0BBeeyTDyOXV84WEg                       Flower Child
# 34  YKQV3jWLube1MbrkGV5HWw                   Elevation Burger
# 35  QBgGlRhti1ALQ8NlJfKvAg  Sweet Sosumba Jamaican Vegan Cafe
#
#                               categories  num_categories  price  review_count  \
# 0                               [indpak]               1      2           879
# 1                               [indpak]               1      3          3127
# 2                               [indpak]               1      2           389
# 3                               [indpak]               1      2           305
# 4                               [indpak]               1      2           412
# ..                                   ...             ...    ...           ...
# 31  [newamerican, icecream, gluten_free]               3      2           264
# 32                  [foodtrucks, indpak]               2      0             3
# 33      [salad, newamerican, vegetarian]               3      2           114
# 34    [burgers, newamerican, vegetarian]               3      1           423
# 35                    [vegan, caribbean]               2      0            87
#
#     rating            street_address            city state zip_code
# 0      4.5               243 K St NE  Washington, DC    DC    20002
# 1      4.5               633 D St NW  Washington, DC    DC    20004
# 2      4.0           1413 Park Rd NW  Washington, DC    DC    20010
# 3      4.0           1317 14th St NW  Washington, DC    DC    20005
# 4      4.5          1247 First St SE  Washington, DC    DC    20003
# ..     ...                       ...             ...   ...      ...
# 31     3.5      3950 Chain Bridge Rd         Fairfax    VA    22030
# 32     2.0            1000 4th St SW  Washington, DC    DC    20024
# 33     4.0  2112 Pennsylvania Ave NW  Washington, DC    DC    20037
# 34     3.0       442 S Washington St    Falls Church    VA    22046
# 35     4.5       3501 Georgia Ave NW  Washington, DC    DC    20010
#
# [386 rows x 11 columns]

# %%
all_results_la.shape
# Out:
# (0, 11)

# %%
all_results_dc.shape
# Out:
# (9, 11)

# %%
response.status_code
# Out:
# 200
